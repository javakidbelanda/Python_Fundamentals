# %%
def is_even(number):
    if number % 2 == 0:
        return True
    else:
        return False

# %%
print (is_even(4))
print (is_even(7))
# Out:
# True
# False

# %% [raw]
#     results = [is_even (n) for n in range(1,21)]
